# %%
from polyglot.downloader import downloader
downloader.download("embeddings2.en")
downloader.download("embeddings2.hi")
downloader.download("embeddings2.ta")
downloader.download("transliteration2.hi")
downloader.download("transliteration2.ta")
# Out:
# [polyglot_data] Downloading package embeddings2.en to
# [polyglot_data]     /home/ubuntu/polyglot_data...
# [polyglot_data]   Package embeddings2.en is already up-to-date!
# [polyglot_data] Downloading package embeddings2.hi to
# [polyglot_data]     /home/ubuntu/polyglot_data...
# [polyglot_data]   Package embeddings2.hi is already up-to-date!
# [polyglot_data] Downloading package embeddings2.ta to
# [polyglot_data]     /home/ubuntu/polyglot_data...
# [polyglot_data]   Package embeddings2.ta is already up-to-date!
# [polyglot_data] Downloading package transliteration2.hi to
# [polyglot_data]     /home/ubuntu/polyglot_data...
# [polyglot_data]   Package transliteration2.hi is already up-to-date!
# [polyglot_data] Downloading package transliteration2.ta to
# [polyglot_data]     /home/ubuntu/polyglot_data...
# [polyglot_data]   Package transliteration2.ta is already up-to-date!
# True

# %%
from datasets import load_dataset, load_metric, Audio

common_voice_train = load_dataset("common_voice", "ta", split="train+validation")
common_voice_test = load_dataset("common_voice", "ta", split="test")
# Out:
# Reusing dataset common_voice (/home/ubuntu/.cache/huggingface/datasets/common_voice/ta/6.1.0/f7a9d973839b7706e9e281c19b7e512f31badf3c0fdbd21c671f3c4bf9acf3b9)
# Reusing dataset common_voice (/home/ubuntu/.cache/huggingface/datasets/common_voice/ta/6.1.0/f7a9d973839b7706e9e281c19b7e512f31badf3c0fdbd21c671f3c4bf9acf3b9)

# %%
common_voice_train = common_voice_train.remove_columns(["accent", "age", "client_id", "down_votes", "gender", "locale", "segment", "up_votes"])
common_voice_test = common_voice_test.remove_columns(["accent", "age", "client_id", "down_votes", "gender", "locale", "segment", "up_votes"])

# %%
import re
import polyglot
from polyglot.text import Text
chars_to_ignore_regex = '[\,\?\.\!\-\;\:\"\“\%\‘\”\�]'


def get_transliterations(batch):
    batch["sentence"] = Text(batch["sentence"], hint_language_code="ta")
    batch["sentence"] = (" ".join(list(batch["sentence"].transliterate("en"))))
    return batch

def remove_special_characters(batch):
    batch["sentence"] = re.sub(chars_to_ignore_regex, '', batch["sentence"]).upper() + " "
    return batch

# %%
common_voice_train = common_voice_train.map(get_transliterations)
common_voice_test = common_voice_test.map(get_transliterations)
# Out:
# Loading cached processed dataset at /home/ubuntu/.cache/huggingface/datasets/common_voice/ta/6.1.0/f7a9d973839b7706e9e281c19b7e512f31badf3c0fdbd21c671f3c4bf9acf3b9/cache-cb78d13a18c59b24.arrow
# Loading cached processed dataset at /home/ubuntu/.cache/huggingface/datasets/common_voice/ta/6.1.0/f7a9d973839b7706e9e281c19b7e512f31badf3c0fdbd21c671f3c4bf9acf3b9/cache-6994764b3354d72b.arrow

# %%
common_voice_train = common_voice_train.map(remove_special_characters)
common_voice_test = common_voice_test.map(remove_special_characters)
# Out:
# Loading cached processed dataset at /home/ubuntu/.cache/huggingface/datasets/common_voice/ta/6.1.0/f7a9d973839b7706e9e281c19b7e512f31badf3c0fdbd21c671f3c4bf9acf3b9/cache-94ecb9b3bb2b13fb.arrow
# Loading cached processed dataset at /home/ubuntu/.cache/huggingface/datasets/common_voice/ta/6.1.0/f7a9d973839b7706e9e281c19b7e512f31badf3c0fdbd21c671f3c4bf9acf3b9/cache-5929366350c9515c.arrow

# %%
from transformers import Wav2Vec2CTCTokenizer

tokenizer = Wav2Vec2CTCTokenizer("config/vocab.json", unk_token="<unk>", pad_token="<pad>", word_delimiter_token="|")

# %%
from transformers import Wav2Vec2FeatureExtractor

feature_extractor = Wav2Vec2FeatureExtractor(feature_size=1, sampling_rate=16000, padding_value=0.0, do_normalize=True, return_attention_mask=True)

# %%
from transformers import Wav2Vec2Processor

processor = Wav2Vec2Processor(feature_extractor=feature_extractor, tokenizer=tokenizer)

# %%
common_voice_train[0]["audio"]
# Out:
# {'path': '/home/ubuntu/.cache/huggingface/datasets/downloads/extracted/bbc7e5ef7e1baed3b86a20ce9e146e069a26e1bebd1feadc09a550c84ff03cf0/cv-corpus-6.1-2020-12-11/ta/clips/common_voice_ta_19171502.mp3',
#  'array': array([0.        , 0.        , 0.        , ..., 0.00075823, 0.00074035,
#         0.00111735], dtype=float32),
#  'sampling_rate': 48000}

# %%
common_voice_train = common_voice_train.cast_column("audio", Audio(sampling_rate=16_000))
common_voice_test = common_voice_test.cast_column("audio", Audio(sampling_rate=16_000))

# %%
common_voice_train[0]["audio"]
# Out:
# {'path': '/home/ubuntu/.cache/huggingface/datasets/downloads/extracted/bbc7e5ef7e1baed3b86a20ce9e146e069a26e1bebd1feadc09a550c84ff03cf0/cv-corpus-6.1-2020-12-11/ta/clips/common_voice_ta_19171502.mp3',
#  'array': array([0.        , 0.        , 0.        , ..., 0.00103243, 0.00046855,
#         0.00098617], dtype=float32),
#  'sampling_rate': 16000}

# %%
import random
rand_int = random.randint(0, len(common_voice_train)-1)

print("Target text:", common_voice_train[rand_int]["sentence"])
print("Input array shape:", common_voice_train[rand_int]["audio"]["array"].shape)
print("Sampling rate:", common_voice_train[rand_int]["audio"]["sampling_rate"])
# Out:
# Target text: VERNRI EDDUTHIKU MURNRILUME SENRU
# Input array shape: (56832,)
# Sampling rate: 16000

# %%
def prepare_dataset(batch):
    audio = batch["audio"]

    # batched output is "un-batched"
    batch["input_values"] = processor(audio["array"], sampling_rate=audio["sampling_rate"]).input_values[0]
    
    with processor.as_target_processor():
        batch["labels"] = processor(batch["sentence"]).input_ids
    return batch

# %%
common_voice_train = common_voice_train.map(prepare_dataset, remove_columns=common_voice_train.column_names)
common_voice_test = common_voice_test.map(prepare_dataset, remove_columns=common_voice_test.column_names)
# Out:
#   0%|          | 0/3788 [00:00<?, ?ex/s]
# Loading cached processed dataset at /home/ubuntu/.cache/huggingface/datasets/common_voice/ta/6.1.0/f7a9d973839b7706e9e281c19b7e512f31badf3c0fdbd21c671f3c4bf9acf3b9/cache-af227e453f83ffbe.arrow

# %%
import torch

from dataclasses import dataclass, field
from typing import Any, Dict, List, Optional, Union

@dataclass
class DataCollatorCTCWithPadding:
    """
    Data collator that will dynamically pad the inputs received.
    Args:
        processor (:class:`~transformers.Wav2Vec2Processor`)
            The processor used for proccessing the data.
        padding (:obj:`bool`, :obj:`str` or :class:`~transformers.tokenization_utils_base.PaddingStrategy`, `optional`, defaults to :obj:`True`):
            Select a strategy to pad the returned sequences (according to the model's padding side and padding index)
            among:
            * :obj:`True` or :obj:`'longest'`: Pad to the longest sequence in the batch (or no padding if only a single
              sequence if provided).
            * :obj:`'max_length'`: Pad to a maximum length specified with the argument :obj:`max_length` or to the
              maximum acceptable input length for the model if that argument is not provided.
            * :obj:`False` or :obj:`'do_not_pad'` (default): No padding (i.e., can output a batch with sequences of
              different lengths).
        max_length (:obj:`int`, `optional`):
            Maximum length of the ``input_values`` of the returned list and optionally padding length (see above).
        max_length_labels (:obj:`int`, `optional`):
            Maximum length of the ``labels`` returned list and optionally padding length (see above).
        pad_to_multiple_of (:obj:`int`, `optional`):
            If set will pad the sequence to a multiple of the provided value.
            This is especially useful to enable the use of Tensor Cores on NVIDIA hardware with compute capability >=
            7.5 (Volta).
    """

    processor: Wav2Vec2Processor
    padding: Union[bool, str] = True
    max_length: Optional[int] = None
    max_length_labels: Optional[int] = None
    pad_to_multiple_of: Optional[int] = None
    pad_to_multiple_of_labels: Optional[int] = None

    def __call__(self, features: List[Dict[str, Union[List[int], torch.Tensor]]]) -> Dict[str, torch.Tensor]:
        # split inputs and labels since they have to be of different lenghts and need
        # different padding methods
        input_features = [{"input_values": feature["input_values"]} for feature in features]
        label_features = [{"input_ids": feature["labels"]} for feature in features]

        batch = self.processor.pad(
            input_features,
            padding=self.padding,
            max_length=self.max_length,
            pad_to_multiple_of=self.pad_to_multiple_of,
            return_tensors="pt",
        )
        with self.processor.as_target_processor():
            labels_batch = self.processor.pad(
                label_features,
                padding=self.padding,
                max_length=self.max_length_labels,
                pad_to_multiple_of=self.pad_to_multiple_of_labels,
                return_tensors="pt",
            )

        # replace padding with -100 to ignore loss correctly
        labels = labels_batch["input_ids"].masked_fill(labels_batch.attention_mask.ne(1), -100)

        batch["labels"] = labels

        return batch

# %%
data_collator = DataCollatorCTCWithPadding(processor=processor, padding=True)

# %%
wer_metric = load_metric("wer")

# %%
import numpy as np
def compute_metrics(pred):
    pred_logits = pred.predictions
    pred_ids = np.argmax(pred_logits, axis=-1)

    pred.label_ids[pred.label_ids == -100] = processor.tokenizer.pad_token_id

    pred_str = processor.batch_decode(pred_ids)
    # we do not want to group tokens when computing the metrics
    label_str = processor.batch_decode(pred.label_ids, group_tokens=False)

    wer = wer_metric.compute(predictions=pred_str, references=label_str)

    return {"wer": wer}

# %%
from transformers import Wav2Vec2ForCTC

model = Wav2Vec2ForCTC.from_pretrained(
    "facebook/wav2vec2-large-xlsr-53", 
    attention_dropout=0.1,
    hidden_dropout=0.1,
    feat_proj_dropout=0.0,
    mask_time_prob=0.05,
    layerdrop=0.1,
    ctc_loss_reduction="mean", 
    pad_token_id=processor.tokenizer.pad_token_id,
    vocab_size=len(processor.tokenizer)
)
# Out:
# Some weights of the model checkpoint at facebook/wav2vec2-large-xlsr-53 were not used when initializing Wav2Vec2ForCTC: ['project_q.weight', 'project_q.bias', 'quantizer.codevectors', 'quantizer.weight_proj.weight', 'quantizer.weight_proj.bias', 'project_hid.bias', 'project_hid.weight']
# - This IS expected if you are initializing Wav2Vec2ForCTC from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing Wav2Vec2ForCTC from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of Wav2Vec2ForCTC were not initialized from the model checkpoint at facebook/wav2vec2-large-xlsr-53 and are newly initialized: ['lm_head.weight', 'lm_head.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
model.freeze_feature_extractor()
model.gradient_checkpointing_enable()

# %%
from transformers import TrainingArguments

training_args = TrainingArguments(
  output_dir="wav2vec2-large-rbg-tamil",
  group_by_length=True,
  per_device_train_batch_size=16,
  gradient_accumulation_steps=2,
  evaluation_strategy="steps",
  num_train_epochs=50,
  fp16=True,
  save_steps=100,
  eval_steps=100,
  logging_steps=10,
  learning_rate=3e-4,
  warmup_steps=500,
  save_total_limit=2,
)

# %%
from transformers import Trainer

trainer = Trainer(
    model=model,
    data_collator=data_collator,
    args=training_args,
    compute_metrics=compute_metrics,
    train_dataset=common_voice_train,
    eval_dataset=common_voice_test,
    tokenizer=processor.feature_extractor,
)
# Out:
# Using amp fp16 backend

# %%
trainer.train()
# Out:
# ***** Running training *****
#   Num examples = 3788
#   Num Epochs = 50
#   Instantaneous batch size per device = 16
#   Total train batch size (w. parallel, distributed & accumulation) = 32
#   Gradient Accumulation steps = 2
#   Total optimization steps = 5900
# /home/ubuntu/environments/t-seed/lib/python3.8/site-packages/transformers/feature_extraction_utils.py:158: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at  ../torch/csrc/utils/tensor_new.cpp:201.)
#   tensor = as_tensor(value)
# /home/ubuntu/environments/t-seed/lib/python3.8/site-packages/transformers/models/wav2vec2/modeling_wav2vec2.py:882: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   return (input_length - kernel_size) // stride + 1
#     <div>
#
#       <progress value='5900' max='5900' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [5900/5900 8:43:37, Epoch 49/50]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Wer</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>100</td>
#       <td>4.316100</td>
#       <td>3.703673</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>2.972100</td>
#       <td>3.014820</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>2.911600</td>
#       <td>2.948166</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>2.850400</td>
#       <td>2.874598</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>1.782500</td>
#       <td>1.644625</td>
#       <td>1.001128</td>
#     </tr>
#     <tr>
#       <td>600</td>
#       <td>1.097800</td>
#       <td>1.024536</td>
#       <td>0.882154</td>
#     </tr>
#     <tr>
#       <td>700</td>
#       <td>0.827700</td>
#       <td>0.929936</td>
#       <td>0.819425</td>
#     </tr>
#     <tr>
#       <td>800</td>
#       <td>0.759700</td>
#       <td>0.807461</td>
#       <td>0.785171</td>
#     </tr>
#     <tr>
#       <td>900</td>
#       <td>0.675900</td>
#       <td>0.815721</td>
#       <td>0.777559</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.578700</td>
#       <td>0.771042</td>
#       <td>0.747251</td>
#     </tr>
#     <tr>
#       <td>1100</td>
#       <td>0.469600</td>
#       <td>0.772844</td>
#       <td>0.729490</td>
#     </tr>
#     <tr>
#       <td>1200</td>
#       <td>0.470800</td>
#       <td>0.790337</td>
#       <td>0.711164</td>
#     </tr>
#     <tr>
#       <td>1300</td>
#       <td>0.475200</td>
#       <td>0.777692</td>
#       <td>0.703411</td>
#     </tr>
#     <tr>
#       <td>1400</td>
#       <td>0.435500</td>
#       <td>0.816255</td>
#       <td>0.715252</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>0.335100</td>
#       <td>0.814221</td>
#       <td>0.684381</td>
#     </tr>
#     <tr>
#       <td>1600</td>
#       <td>0.377200</td>
#       <td>0.819247</td>
#       <td>0.691006</td>
#     </tr>
#     <tr>
#       <td>1700</td>
#       <td>0.315900</td>
#       <td>0.882730</td>
#       <td>0.686496</td>
#     </tr>
#     <tr>
#       <td>1800</td>
#       <td>0.296000</td>
#       <td>0.887461</td>
#       <td>0.683958</td>
#     </tr>
#     <tr>
#       <td>1900</td>
#       <td>0.257200</td>
#       <td>0.892571</td>
#       <td>0.683676</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>0.264400</td>
#       <td>0.894147</td>
#       <td>0.682267</td>
#     </tr>
#     <tr>
#       <td>2100</td>
#       <td>0.278700</td>
#       <td>0.856509</td>
#       <td>0.676346</td>
#     </tr>
#     <tr>
#       <td>2200</td>
#       <td>0
config.json
# Model weights saved in wav2vec2-large-rbg-tamil/checkpoint-900/pytorch_model.bin
# Configuration saved in wav2vec2-large-rbg-tamil/checkpoint-900/preprocessor_config.json
# Deleting older checkpoint [wav2vec2-large-rbg-tamil/checkpoint-700] due to args.save_total_limit
# /home/ubuntu/environments/t-seed/lib/python3.8/site-packages/transformers/models/wav2vec2/modeling_wav2vec2.py:882: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   return (input_length - kernel_size) // stride + 1
# ***** Running Evaluation *****
#   Num examples = 1781
#   Batch size = 8
# Saving model checkpoint to wav2vec2-large-rbg-tamil/checkpoint-1000
# Configuration saved in wav2vec2-large-rbg-tamil/checkpoint-1000/config.json
# Model weights saved in wav2vec2-large-rbg-tamil/checkpoint-1000/pytorch_model.bin
# Configuration saved in wav2vec2-large-rbg-tamil/checkpoint-1000/preprocessor_config.json
# Deleting older checkpoint [wav2vec2-large-rbg-tamil/checkpoint-800] due to args.save_total_limit
# /home/ubuntu/environments/t-seed/lib/python3.8/site-packages/transformers/models/wav2vec2/modeling_wav2vec2.py:882: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   return (input_length - kernel_size) // stride + 1
# ***** Running Evaluation *****
#   Num examples = 1781
#   Batch size = 8
# Saving model checkpoint to wav2vec2-large-rbg-tamil/checkpoint-1100
# Configuration saved in wav2vec2-large-rbg-tamil/checkpoint-1100/config.json
# Model weights saved in wav2vec2-large-rbg-tamil/checkpoint-1100/pytorch_model.bin
# Configuration saved in wav2vec2-large-rbg-tamil/checkpoint-1100/preprocessor_config.json
# Deleting older checkpoint [wav2vec2-large-rbg-tamil/checkpoint-900] due to args.save_total_limit
# /home/ubuntu/environments/t-seed/lib/python3.8/site-packages/transformers/models/wav2vec2/modeling_wav2vec2.py:882: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   return (input_length - kernel_size) // stride + 1
# ***** Running Evaluation *****
#   Num examples = 1781
#   Batch size = 8
# Saving model checkpoint to wav2vec2-large-rbg-tamil/checkpoint-1200
# Configuration saved in wav2vec2-large-rbg-tamil/checkpoint-1200/config.json
# Model weights saved in wav2vec2-large-rbg-tamil/checkpoint-1200/pytorch_model.bin
# Configuration saved in wav2vec2-large-rbg-tamil/checkpoint-1200/preprocessor_config.json
# Deleting older checkpoint [wav2vec2-large-rbg-tamil/checkpoint-1000] due to args.save_total_limit
# /home/ubuntu/environments/t-seed/lib/python3.8/site-packages/transformers/models/wav2vec2/modeling_wav2vec2.py:882: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   return (input_length - kernel_size) // stride + 1
# ***** Running Evaluation *****
#   Num examples = 1781
#   Batch size = 8
# Saving model checkpoint to wav2vec2-large-rbg-tamil/checkpoint-1300
# Configuration saved in wav2vec2-large-rbg-tamil/checkpoint-1300/config.json
# Model weights saved in wav2vec2-large-rbg-tamil/checkpoint-1300/pytorch_model.bin
# Configuration saved in wav2vec2-large-rbg-tamil/checkpoint-1300/preprocessor_config.json
# Deleting older checkpoint [wav2vec2-large-rbg-tamil/checkpoint-1100] due to args.save_total_limit
# /home/ubuntu/environments/t-seed/lib/python3.8/site-packages/transformers/models/wav2vec2/modeling_wav2vec2.py:882: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   return (input_length - kernel_size) // stride + 1
# ***** Running Evaluation *****
#   Num examples = 1781
#   Batch size = 8
# Saving model checkpoint to wav2vec2-large-rbg-tamil/checkpoint-1400
# Configuration saved in wav2vec2-large-rbg-tamil/checkpoint-1400/config.json
# Model weights saved in wav2vec2-large-rbg-tamil/checkpoint-1400/pytorch_model.bin
# Configuration saved in wav2vec2-large-rbg-tamil/checkpoint-1400/preprocessor_config.json
# Deleting older checkpoint [wav2vec2-large-rbg-tamil/checkpoint-1200] due to args.save_total_limit
# /home/ubuntu/environments/t-seed/lib/python3.8/site-packages/transformers/models/wav2vec2/modeling_wav2vec2.py:882: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   return (input_length - kernel_size) // stride + 1
# ***** Running Evaluation *****
#   Num examples = 1781
#   Batch size = 8
# Saving model checkpoint to wav2vec2-large-rbg-tamil/checkpoint-1500
# Configuration saved in wav2vec2-large-rbg-tamil/checkpoint-1500/config.json
# Model weights saved in wav2vec2-large-rbg-tamil/checkpoint-1500/pytorch_model.bin
# Configuration saved in wav2vec2-large-rbg-tamil/checkpoint-1500/preprocessor_config.json
# Deleting older checkpoint [wav2vec2-large-rbg-tamil/checkpoint-1300] due to args.save_total_limit
# /home/ubuntu/environments/t-seed/lib/python3.8/site-packages/transformers/models/wav2vec2/modeling_wav2vec2.py:882: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   return (input_length - kernel_size) // stride + 1
# ***** Running Evaluation *****
#   Num examples = 1781
#   Batch size = 8
# Saving model checkpoint to wav2vec2-large-rbg-tamil/checkpoint-1600
# Configuration saved in wav2vec2-large-rbg-tamil/checkpoint-1600/config.json
# Model weights saved in wav2vec2-large-rbg-tamil/checkpoint-1600/pytorch_model.bin
# Configuration saved in wav2vec2-large-rbg-tamil/checkpoint-1600/preprocessor_config.json
# Deleting older checkpoint [wav2vec2-large-rbg-tamil/checkpoint-1400] due to args.save_total_limit
# /home/ubuntu/environments/t-seed/lib/python3.8/site-packages/transformers/models/wav2vec2/modeling_wav2vec2.py:882: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   return (input_length - kernel_size) // stride + 1
# ***** Running Evaluation *****
#   Num examples = 1781
#   Batch size = 8
# Saving model checkpoint to wav2vec2-large-rbg-tamil/checkpoint-1700
# Configuration saved in wav2vec2-large-rbg-tamil/checkpoint-1700/config.json
# Model weights saved in wav2vec2-large-rbg-tamil/checkpoint-1700/pytorch_model.bin
# Configuration saved in wav2vec2-large-rbg-tamil/checkpoint-1700/preprocessor_config.json
# Deleting older checkpoint [wav2vec2-large-rbg-tamil/checkpoint-1500] due to args.save_total_limit
# /home/ubuntu/environments/t-seed/lib/python3.8/site-packages/transformers/models/wav2vec2/modeling_wav2vec2.py:882: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   return (input_length - kernel_size) // stride + 1
# ***** Running Evaluation *****
#   Num examples = 1781
#   Batch size = 8
# Saving model checkpoint to wav2vec2-large-rbg-tamil/checkpoint-1800
# Configuration saved in wav2vec2-large-rbg-tamil/checkpoint-1800/config.json
# Model weights saved in wav2vec2-large-rbg-tamil/checkpoint-1800/pytorch_model.bin
# Configuration saved in wav2vec2-large-rbg-tamil/checkpoint-1800/preprocessor_config.json
# Deleting older checkpoint [wav2vec2-large-rbg-tamil/checkpoint-1600] due to args.save_total_limit
# /home/ubuntu/environments/t-seed/lib/python3.8/site-packages/transformers/models/wav2vec2/modeling_wav2vec2.py:882: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   return (input_length - kernel_size) // stride + 1
# ***** Running Evaluation *****
#   Num examples = 1781
#   Batch size = 8
# Saving model checkpoint to wav2vec2-large-rbg-tamil/checkpoint-1900
# Configuration saved in wav2vec2-large-rbg-tamil/checkpoint-1900/config.json
# Model weights saved in wav2vec2-large-rbg-tamil/checkpoint-1900/pytorch_model.bin
# Configuration saved in wav2vec2-large-rbg-tamil/checkpoint-1900/preprocessor_config.json
# Deleting older checkpoint [wav2vec2-large-rbg-tamil/checkpoint-1700] due to args.save_total_limit
# /home/ubuntu/environments/t-seed/lib/python3.8/site-packages/transformers/models/wav2vec2/modeling_wav2vec2.py:882: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   return (input_length - kernel_size) // stride + 1
# ***** Running Evaluation *****
#   Num examples = 1781
#   Batch size = 8
# Saving model checkpoint to wav2vec2-large-rbg-tamil/checkpoint-2000
# Configuration saved in wav2vec2-large-rbg-tamil/checkpoint-2000/config.json
# Model weights saved in wav2vec2-large-rbg-tamil/checkpoint-2000/pytorch_model.bin
# Configuration saved in wav2vec2-large-rbg-tamil/checkpoint-2000/preprocessor_config.json
# Deleting older checkpoint [wav2vec2-large-rbg-tamil/checkpoint-1800] due to args.save_total_limit
# /home/ubuntu/environments/t-seed/lib/python3.8/site-packages/transformers/models/wav2vec2/modeling_wav2vec2.py:882: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   return (input_length - kernel_size) // stride + 1
# ***** Running Evaluation *****
#   Num examples = 1781
#   Batch size = 8
# Saving model checkpoint to wav2vec2-large-rbg-tamil/checkpoint-2100
# Configuration saved in wav2vec2-large-rbg-tamil/checkpoint-2100/config.json
# Model weights saved in wav2vec2-large-rbg-tamil/checkpoint-2100/pytorch_model.bin
# Configuration saved in wav2vec2-large-rbg-tamil/checkpoint-2100/preprocessor_config.json
# Deleting older checkpoint [wav2vec2-large-rbg-tamil/checkpoint-1900] due to args.save_total_limit
# /home/ubuntu/environments/t-seed/lib/python3.8/site-packages/transformers/models/wav2vec2/modeling_wav2vec2.py:882: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   return (input_length - kernel_size) // stride + 1
# ***** Running Evaluation *****
#   Num examples = 1781
#   Batch size = 8
# Saving model checkpoint to wav2vec2-large-rbg-tamil/checkpoint-2200
# Configuration saved in wav2vec2-large-rbg-tamil/checkpoint-2200/config.json
# Model weights saved in wav2vec2-large-rbg-tamil/checkpoint-2200/pytorch_model.bin
# Configuration saved in wav2vec2-large-rbg-tamil/checkpoint-2200/preprocessor_config.json
# Deleting older checkpoint [wav2vec2-large-rbg-tamil/checkpoint-2000] due to args.save_total_limit
# /home/ubuntu/environments/t-seed/lib/python3.8/site-packages/transformers/models/wav2vec2/modeling_wav2vec2.py:882: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   return (input_length - kernel_size) // stride + 1
# ***** Running Evaluation *****
#   Num examples = 1781
#   Batch size = 8
# Saving model checkpoint to wav2vec2-large-rbg-tamil/checkpoint-2300
# Configuration saved in wav2vec2-large-rbg-tamil/checkpoint-2300/config.json
# Model weights saved in wav2vec2-large-rbg-tamil/checkpoint-2300/pytorch_model.bin
# Configuration saved in wav2vec2-large-rbg-tamil/checkpoint-2300/preprocessor_config.json
# Deleting older checkpoint [wav2vec2-large-rbg-tamil/checkpoint-2100] due to args.save_total_limit
# /home/ubuntu/environments/t-seed/lib/python3.8/site-packages/transformers/models/wav2vec2/modeling_wav2vec2.py:882: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   return (input_length - kernel_size) // stride + 1
# ***** Running Evaluation *****
#   Num examples = 1781
#   Batch size = 8
# Saving model checkpoint to wav2vec2-large-rbg-tamil/checkpoint-2400
# Configuration saved in wav2vec2-large-rbg-tamil/checkpoint-2400/config.json
# Model weights saved in wav2vec2-large-rbg-tamil/checkpoint-2400/pytorch_model.bin
# Configuration saved in wav2vec2-large-rbg-tamil/checkpoint-2400/preprocessor_config.json
# Deleting older checkpoint [wav2vec2-large-rbg-tamil/checkpoint-2200] due to args.save_total_limit
# /home/ubuntu/environments/t-seed/lib/python3.8/site-packages/transformers/models/wav2vec2/modeling_wav2vec2.py:882: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   return (input_length - kernel_size) // stride + 1
# ***** Running Evaluation *****
#   Num examples = 1781
#   Batch size = 8
# Saving model checkpoint to wav2vec2-large-rbg-tamil/checkpoint-2500
# Configuration saved in wav2vec2-large-rbg-tamil/checkpoint-2500/config.json
# Model weights saved in wav2vec2-large-rbg-tamil/checkpoint-2500/pytorch_model.bin
# Configuration saved in wav2vec2-large-rbg-tamil/checkpoint-2500/preprocessor_config.json
# Deleting older checkpoint [wav2vec2-large-rbg-tamil/checkpoint-2300] due to args.save_total_limit
# /home/ubuntu/environments/t-seed/lib/python3.8/site-packages/transformers/models/wav2vec2/modeling_wav2vec2.py:882: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   return (input_length - kernel_size) // stride + 1
# ***** Running Evaluation *****
#   Num examples = 1781
#   Batch size = 8
# Saving model checkpoint to wav2vec2-large-rbg-tamil/checkpoint-2600
# Configuration saved in wav2vec2-large-rbg-tamil/checkpoint-2600/config.json
# Model weights saved in wav2vec2-large-rbg-tamil/checkpoint-2600/pytorch_model.bin
# Configuration saved in wav2vec2-large-rbg-tamil/checkpoint-2600/preprocessor_config.json
# Deleting older checkpoint [wav2vec2-large-rbg-tamil/checkpoint-2400] due to args.save_total_limit
# /home/ubuntu/environments/t-seed/lib/python3.8/site-packages/transformers/models/wav2vec2/modeling_wav2vec2.py:882: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   return (input_length - kernel_size) // stride + 1
# ***** Running Evaluation *****
#   Num examples = 1781
#   Batch size = 8
# Saving model checkpoint to wav2vec2-large-rbg-tamil/checkpoint-2700
# Configuration saved in wav2vec2-large-rbg-tamil/checkpoint-2700/config.json
# Model weights saved in wav2vec2-large-rbg-tamil/checkpoint-2700/pytorch_model.bin
# Configuration saved in wav2vec2-large-rbg-tamil/checkpoint-2700/preprocessor_config.json
# Deleting older checkpoint [wav2vec2-large-rbg-tamil/checkpoint-2500] due to args.save_total_limit
# /home/ubuntu/environments/t-seed/lib/python3.8/site-packages/transformers/models/wav2vec2/modeling_wav2vec2.py:882: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   return (input_length - kernel_size) // stride + 1
# ***** Running Evaluation *****
#   Num examples = 1781
#   Batch size = 8
# Saving model checkpoint to wav2vec2-large-rbg-tamil/checkpoint-2800
# Configuration saved in wav2vec2-large-rbg-tamil/checkpoint-2800/config.json
# Model weights saved in wav2vec2-large-rbg-tamil/checkpoint-2800/pytorch_model.bin
# Configuration saved in wav2vec2-large-rbg-tamil/checkpoint-2800/preprocessor_config.json
# Deleting older checkpoint [wav2vec2-large-rbg-tamil/checkpoint-2600] due to args.save_total_limit
# /home/ubuntu/environments/t-seed/lib/python3.8/site-packages/transformers/models/wav2vec2/modeling_wav2vec2.py:882: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   return (input_length - kernel_size) // stride + 1
# ***** Running Evaluation *****
#   Num examples = 1781
#   Batch size = 8
# Saving model checkpoint to wav2vec2-large-rbg-tamil/checkpoint-2900
# Configuration saved in wav2vec2-large-rbg-tamil/checkpoint-2900/config.json
# Model weights saved in wav2vec2-large-rbg-tamil/checkpoint-2900/pytorch_model.bin
# Configuration saved in wav2vec2-large-rbg-tamil/checkpoint-2900/preprocessor_config.json
# Deleting older checkpoint [wav2vec2-large-rbg-tamil/checkpoint-2700] due to args.save_total_limit
# /home/ubuntu/environments/t-seed/lib/python3.8/site-packages/transformers/models/wav2vec2/modeling_wav2vec2.py:882: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   return (input_length - kernel_size) // stride + 1
# ***** Running Evaluation *****
#   Num examples = 1781
#   Batch size = 8
# Saving model checkpoint to wav2vec2-large-rbg-tamil/checkpoint-3000
# Configuration saved in wav2vec2-large-rbg-tamil/checkpoint-3000/config.json
# Model weights saved in wav2vec2-large-rbg-tamil/checkpoint-3000/pytorch_model.bin
# Configuration saved in wav2vec2-large-rbg-tamil/checkpoint-3000/preprocessor_config.json
# Deleting older checkpoint [wav2vec2-large-rbg-tamil/checkpoint-2800] due to args.save_total_limit
# /home/ubuntu/environments/t-seed/lib/python3.8/site-packages/transformers/models/wav2vec2/modeling_wav2vec2.py:882: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   return (input_length - kernel_size) // stride + 1
# ***** Running Evaluation *****
#   Num examples = 1781
#   Batch size = 8
# Saving model checkpoint to wav2vec2-large-rbg-tamil/checkpoint-3100
# Configuration saved in wav2vec2-large-rbg-tamil/checkpoint-3100/config.json
# Model weights saved in wav2vec2-large-rbg-tamil/checkpoint-3100/pytorch_model.bin
# Configuration saved in wav2vec2-large-rbg-tamil/checkpoint-3100/preprocessor_config.json
# Deleting older checkpoint [wav2vec2-large-rbg-tamil/checkpoint-2900] due to args.save_total_limit
# /home/ubuntu/environments/t-seed/lib/python3.8/site-packages/transformers/models/wav2vec2/modeling_wav2vec2.py:882: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   return (input_length - kernel_size) // stride + 1
# ***** Running Evaluation *****
#   Num examples = 1781
#   Batch size = 8
# Saving model checkpoint to wav2vec2-large-rbg-tamil/checkpoint-3200
# Configuration saved in wav2vec2-large-rbg-tamil/checkpoint-3200/config.json
# Model weights saved in wav2vec2-large-rbg-tamil/checkpoint-3200/pytorch_model.bin
# Configuration saved in wav2vec2-large-rbg-tamil/checkpoint-3200/preprocessor_config.json
# Deleting older checkpoint [wav2vec2-large-rbg-tamil/checkpoint-3000] due to args.save_total_limit
# /home/ubuntu/environments/t-seed/lib/python3.8/site-packages/transformers/models/wav2vec2/modeling_wav2vec2.py:882: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   return (input_length - kernel_size) // stride + 1
# ***** Running Evaluation *****
#   Num examples = 1781
#   Batch size = 8
# Saving model checkpoint to wav2vec2-large-rbg-tamil/checkpoint-3300
# Configuration saved in wav2vec2-large-rbg-tamil/checkpoint-3300/config.json
# Model weights saved in wav2vec2-large-rbg-tamil/checkpoint-3300/pytorch_model.bin
# Configuration saved in wav2vec2-large-rbg-tamil/checkpoint-3300/preprocessor_config.json
# Deleting older checkpoint [wav2vec2-large-rbg-tamil/checkpoint-3100] due to args.save_total_limit
# /home/ubuntu/environments/t-seed/lib/python3.8/site-packages/transformers/models/wav2vec2/modeling_wav2vec2.py:882: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   return (input_length - kernel_size) // stride + 1
# ***** Running Evaluation *****
#   Num examples = 1781
#   Batch size = 8
# Saving model checkpoint to wav2vec2-large-rbg-tamil/checkpoint-3400
# Configuration saved in wav2vec2-large-rbg-tamil/checkpoint-3400/config.json
# Model weights saved in wav2vec2-large-rbg-tamil/checkpoint-3400/pytorch_model.bin
# Configuration saved in wav2vec2-large-rbg-tamil/checkpoint-3400/preprocessor_config.json
# Deleting older checkpoint [wav2vec2-large-rbg-tamil/checkpoint-3200] due to args.save_total_limit
# /home/ubuntu/environments/t-seed/lib/python3.8/site-packages/transformers/models/wav2vec2/modeling_wav2vec2.py:882: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   return (input_length - kernel_size) // stride + 1
# ***** Running Evaluation *****
#   Num examples = 1781
#   Batch size = 8
# Saving model checkpoint to wav2vec2-large-rbg-tamil/checkpoint-3500
# Configuration saved in wav2vec2-large-rbg-tamil/checkpoint-3500/config.json
# Model weights saved in wav2vec2-large-rbg-tamil/checkpoint-3500/pytorch_model.bin
# Configuration saved in wav2vec2-large-rbg-tamil/checkpoint-3500/preprocessor_config.json
# Deleting older checkpoint [wav2vec2-large-rbg-tamil/checkpoint-3300] due to args.save_total_limit
# /home/ubuntu/environments/t-seed/lib/python3.8/site-packages/transformers/models/wav2vec2/modeling_wav2vec2.py:882: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   return (input_length - kernel_size) // stride + 1
# ***** Running Evaluation *****
#   Num examples = 1781
#   Batch size = 8
# Saving model checkpoint to wav2vec2-large-rbg-tamil/checkpoint-3600
# Configuration saved in wav2vec2-large-rbg-tamil/checkpoint-3600/config.json
# Model weights saved in wav2vec2-large-rbg-tamil/checkpoint-3600/pytorch_model.bin
# Configuration saved in wav2vec2-large-rbg-tamil/checkpoint-3600/preprocessor_config.json
# Deleting older checkpoint [wav2vec2-large-rbg-tamil/checkpoint-3400] due to args.save_total_limit
# /home/ubuntu/environments/t-seed/lib/python3.8/site-packages/transformers/models/wav2vec2/modeling_wav2vec2.py:882: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   return (input_length - kernel_size) // stride + 1
# ***** Running Evaluation *****
#   Num examples = 1781
#   Batch size = 8
# Saving model checkpoint to wav2vec2-large-rbg-tamil/checkpoint-3700
# Configuration saved in wav2vec2-large-rbg-tamil/checkpoint-3700/config.json
# Model weights saved in wav2vec2-large-rbg-tamil/checkpoint-3700/pytorch_model.bin
# Configuration saved in wav2vec2-large-rbg-tamil/checkpoint-3700/preprocessor_config.json
# Deleting older checkpoint [wav2vec2-large-rbg-tamil/checkpoint-3500] due to args.save_total_limit
# /home/ubuntu/environments/t-seed/lib/python3.8/site-packages/transformers/models/wav2vec2/modeling_wav2vec2.py:882: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   return (input_length - kernel_size) // stride + 1
# ***** Running Evaluation *****
#   Num examples = 1781
#   Batch size = 8
# Saving model checkpoint to wav2vec2-large-rbg-tamil/checkpoint-3800
# Configuration saved in wav2vec2-large-rbg-tamil/checkpoint-3800/config.json
# Model weights saved in wav2vec2-large-rbg-tamil/checkpoint-3800/pytorch_model.bin
# Configuration saved in wav2vec2-large-rbg-tamil/checkpoint-3800/preprocessor_config.json
# Deleting older checkpoint [wav2vec2-large-rbg-tamil/checkpoint-3600] due to args.save_total_limit
# /home/ubuntu/environments/t-seed/lib/python3.8/site-packages/transformers/models/wav2vec2/modeling_wav2vec2.py:882: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   return (input_length - kernel_size) // stride + 1
# ***** Running Evaluation *****
#   Num examples = 1781
#   Batch size = 8
# Saving model checkpoint to wav2vec2-large-rbg-tamil/checkpoint-3900
# Configuration saved in wav2vec2-large-rbg-tamil/checkpoint-3900/config.json
# Model weights saved in wav2vec2-large-rbg-tamil/checkpoint-3900/pytorch_model.bin
# Configuration saved in wav2vec2-large-rbg-tamil/checkpoint-3900/preprocessor_config.json
# Deleting older checkpoint [wav2vec2-large-rbg-tamil/checkpoint-3700] due to args.save_total_limit
# /home/ubuntu/environments/t-seed/lib/python3.8/site-packages/transformers/models/wav2vec2/modeling_wav2vec2.py:882: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   return (input_length - kernel_size) // stride + 1
# ***** Running Evaluation *****
# ...
# Configuration saved in wav2vec2-large-rbg-tamil/checkpoint-4400/preprocessor_config.json
# Deleting older checkpoint [wav2vec2-large-rbg-tamil/checkpoint-4200] due to args.save_total_limit
# /home/ubuntu/environments/t-seed/lib/python3.8/site-packages/transformers/models/wav2vec2/modeling_wav2vec2.py:882: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   return (input_length - kernel_size) // stride + 1
# ***** Running Evaluation *****
#   Num examples = 1781
#   Batch size = 8
# Saving model checkpoint to wav2vec2-large-rbg-tamil/checkpoint-4500
# Configuration saved in wav2vec2-large-rbg-tamil/checkpoint-4500/config.json
# Model weights saved in wav2vec2-large-rbg-tamil/checkpoint-4500/pytorch_model.bin
# Configuration saved in wav2vec2-large-rbg-tamil/checkpoint-4500/preprocessor_config.json
# Deleting older checkpoint [wav2vec2-large-rbg-tamil/checkpoint-4300] due to args.save_total_limit
# /home/ubuntu/environments/t-seed/lib/python3.8/site-packages/transformers/models/wav2vec2/modeling_wav2vec2.py:882: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   return (input_length - kernel_size) // stride + 1
# ***** Running Evaluation *****
#   Num examples = 1781
#   Batch size = 8
# Saving model checkpoint to wav2vec2-large-rbg-tamil/checkpoint-4600
# Configuration saved in wav2vec2-large-rbg-tamil/checkpoint-4600/config.json
# Model weights saved in wav2vec2-large-rbg-tamil/checkpoint-4600/pytorch_model.bin
# Configuration saved in wav2vec2-large-rbg-tamil/checkpoint-4600/preprocessor_config.json
# Deleting older checkpoint [wav2vec2-large-rbg-tamil/checkpoint-4400] due to args.save_total_limit
# /home/ubuntu/environments/t-seed/lib/python3.8/site-packages/transformers/models/wav2vec2/modeling_wav2vec2.py:882: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   return (input_length - kernel_size) // stride + 1
# ***** Running Evaluation *****
#   Num examples = 1781
#   Batch size = 8
# Saving model checkpoint to wav2vec2-large-rbg-tamil/checkpoint-4700
# Configuration saved in wav2vec2-large-rbg-tamil/checkpoint-4700/config.json
# Model weights saved in wav2vec2-large-rbg-tamil/checkpoint-4700/pytorch_model.bin
# Configuration saved in wav2vec2-large-rbg-tamil/checkpoint-4700/preprocessor_config.json
# Deleting older checkpoint [wav2vec2-large-rbg-tamil/checkpoint-4500] due to args.save_total_limit
# /home/ubuntu/environments/t-seed/lib/python3.8/site-packages/transformers/models/wav2vec2/modeling_wav2vec2.py:882: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   return (input_length - kernel_size) // stride + 1
# ***** Running Evaluation *****
#   Num examples = 1781
#   Batch size = 8
# Saving model checkpoint to wav2vec2-large-rbg-tamil/checkpoint-4800
# Configuration saved in wav2vec2-large-rbg-tamil/checkpoint-4800/config.json
# Model weights saved in wav2vec2-large-rbg-tamil/checkpoint-4800/pytorch_model.bin
# Configuration saved in wav2vec2-large-rbg-tamil/checkpoint-4800/preprocessor_config.json
# Deleting older checkpoint [wav2vec2-large-rbg-tamil/checkpoint-4600] due to args.save_total_limit
# /home/ubuntu/environments/t-seed/lib/python3.8/site-packages/transformers/models/wav2vec2/modeling_wav2vec2.py:882: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   return (input_length - kernel_size) // stride + 1
# ***** Running Evaluation *****
#   Num examples = 1781
#   Batch size = 8
# Saving model checkpoint to wav2vec2-large-rbg-tamil/checkpoint-4900
# Configuration saved in wav2vec2-large-rbg-tamil/checkpoint-4900/config.json
# Model weights saved in wav2vec2-large-rbg-tamil/checkpoint-4900/pytorch_model.bin
# Configuration saved in wav2vec2-large-rbg-tamil/checkpoint-4900/preprocessor_config.json
# Deleting older checkpoint [wav2vec2-large-rbg-tamil/checkpoint-4700] due to args.save_total_limit
# /home/ubuntu/environments/t-seed/lib/python3.8/site-packages/transformers/models/wav2vec2/modeling_wav2vec2.py:882: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   return (input_length - kernel_size) // stride + 1
# ***** Running Evaluation *****
#   Num examples = 1781
#   Batch size = 8
# Saving model checkpoint to wav2vec2-large-rbg-tamil/checkpoint-5000
# Configuration saved in wav2vec2-large-rbg-tamil/checkpoint-5000/config.json
# Model weights saved in wav2vec2-large-rbg-tamil/checkpoint-5000/pytorch_model.bin
# Configuration saved in wav2vec2-large-rbg-tamil/checkpoint-5000/preprocessor_config.json
# Deleting older checkpoint [wav2vec2-large-rbg-tamil/checkpoint-4800] due to args.save_total_limit
# /home/ubuntu/environments/t-seed/lib/python3.8/site-packages/transformers/models/wav2vec2/modeling_wav2vec2.py:882: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   return (input_length - kernel_size) // stride + 1
# ***** Running Evaluation *****
#   Num examples = 1781
#   Batch size = 8
# Saving model checkpoint to wav2vec2-large-rbg-tamil/checkpoint-5100
# Configuration saved in wav2vec2-large-rbg-tamil/checkpoint-5100/config.json
# Model weights saved in wav2vec2-large-rbg-tamil/checkpoint-5100/pytorch_model.bin
# Configuration saved in wav2vec2-large-rbg-tamil/checkpoint-5100/preprocessor_config.json
# Deleting older checkpoint [wav2vec2-large-rbg-tamil/checkpoint-4900] due to args.save_total_limit
# /home/ubuntu/environments/t-seed/lib/python3.8/site-packages/transformers/models/wav2vec2/modeling_wav2vec2.py:882: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   return (input_length - kernel_size) // stride + 1
# ***** Running Evaluation *****
#   Num examples = 1781
#   Batch size = 8
# Saving model checkpoint to wav2vec2-large-rbg-tamil/checkpoint-5200
# Configuration saved in wav2vec2-large-rbg-tamil/checkpoint-5200/config.json
# Model weights saved in wav2vec2-large-rbg-tamil/checkpoint-5200/pytorch_model.bin
# Configuration saved in wav2vec2-large-rbg-tamil/checkpoint-5200/preprocessor_config.json
# Deleting older checkpoint [wav2vec2-large-rbg-tamil/checkpoint-5000] due to args.save_total_limit
# /home/ubuntu/environments/t-seed/lib/python3.8/site-packages/transformers/models/wav2vec2/modeling_wav2vec2.py:882: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   return (input_length - kernel_size) // stride + 1
# ***** Running Evaluation *****
#   Num examples = 1781
#   Batch size = 8
# Saving model checkpoint to wav2vec2-large-rbg-tamil/checkpoint-5300
# Configuration saved in wav2vec2-large-rbg-tamil/checkpoint-5300/config.json
# Model weights saved in wav2vec2-large-rbg-tamil/checkpoint-5300/pytorch_model.bin
# Configuration saved in wav2vec2-large-rbg-tamil/checkpoint-5300/preprocessor_config.json
# Deleting older checkpoint [wav2vec2-large-rbg-tamil/checkpoint-5100] due to args.save_total_limit
# /home/ubuntu/environments/t-seed/lib/python3.8/site-packages/transformers/models/wav2vec2/modeling_wav2vec2.py:882: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   return (input_length - kernel_size) // stride + 1
# ***** Running Evaluation *****
#   Num examples = 1781
#   Batch size = 8
# Saving model checkpoint to wav2vec2-large-rbg-tamil/checkpoint-5400
# Configuration saved in wav2vec2-large-rbg-tamil/checkpoint-5400/config.json
# Model weights saved in wav2vec2-large-rbg-tamil/checkpoint-5400/pytorch_model.bin
# Configuration saved in wav2vec2-large-rbg-tamil/checkpoint-5400/preprocessor_config.json
# Deleting older checkpoint [wav2vec2-large-rbg-tamil/checkpoint-5200] due to args.save_total_limit
# /home/ubuntu/environments/t-seed/lib/python3.8/site-packages/transformers/models/wav2vec2/modeling_wav2vec2.py:882: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   return (input_length - kernel_size) // stride + 1
# ***** Running Evaluation *****
#   Num examples = 1781
#   Batch size = 8
# Saving model checkpoint to wav2vec2-large-rbg-tamil/checkpoint-5500
# Configuration saved in wav2vec2-large-rbg-tamil/checkpoint-5500/config.json
# Model weights saved in wav2vec2-large-rbg-tamil/checkpoint-5500/pytorch_model.bin
# Configuration saved in wav2vec2-large-rbg-tamil/checkpoint-5500/preprocessor_config.json
# Deleting older checkpoint [wav2vec2-large-rbg-tamil/checkpoint-5300] due to args.save_total_limit
# /home/ubuntu/environments/t-seed/lib/python3.8/site-packages/transformers/models/wav2vec2/modeling_wav2vec2.py:882: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   return (input_length - kernel_size) // stride + 1
# ***** Running Evaluation *****
#   Num examples = 1781
#   Batch size = 8
# Saving model checkpoint to wav2vec2-large-rbg-tamil/checkpoint-5600
# Configuration saved in wav2vec2-large-rbg-tamil/checkpoint-5600/config.json
# Model weights saved in wav2vec2-large-rbg-tamil/checkpoint-5600/pytorch_model.bin
# Configuration saved in wav2vec2-large-rbg-tamil/checkpoint-5600/preprocessor_config.json
# Deleting older checkpoint [wav2vec2-large-rbg-tamil/checkpoint-5400] due to args.save_total_limit
# /home/ubuntu/environments/t-seed/lib/python3.8/site-packages/transformers/models/wav2vec2/modeling_wav2vec2.py:882: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   return (input_length - kernel_size) // stride + 1
# ***** Running Evaluation *****
#   Num examples = 1781
#   Batch size = 8
# Saving model checkpoint to wav2vec2-large-rbg-tamil/checkpoint-5700
# Configuration saved in wav2vec2-large-rbg-tamil/checkpoint-5700/config.json
# Model weights saved in wav2vec2-large-rbg-tamil/checkpoint-5700/pytorch_model.bin
# Configuration saved in wav2vec2-large-rbg-tamil/checkpoint-5700/preprocessor_config.json
# Deleting older checkpoint [wav2vec2-large-rbg-tamil/checkpoint-5500] due to args.save_total_limit
# /home/ubuntu/environments/t-seed/lib/python3.8/site-packages/transformers/models/wav2vec2/modeling_wav2vec2.py:882: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   return (input_length - kernel_size) // stride + 1
# ***** Running Evaluation *****
#   Num examples = 1781
#   Batch size = 8
# Saving model checkpoint to wav2vec2-large-rbg-tamil/checkpoint-5800
# Configuration saved in wav2vec2-large-rbg-tamil/checkpoint-5800/config.json
# Model weights saved in wav2vec2-large-rbg-tamil/checkpoint-5800/pytorch_model.bin
# Configuration saved in wav2vec2-large-rbg-tamil/checkpoint-5800/preprocessor_config.json
# Deleting older checkpoint [wav2vec2-large-rbg-tamil/checkpoint-5600] due to args.save_total_limit
# /home/ubuntu/environments/t-seed/lib/python3.8/site-packages/transformers/models/wav2vec2/modeling_wav2vec2.py:882: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   return (input_length - kernel_size) // stride + 1
# ***** Running Evaluation *****
#   Num examples = 1781
#   Batch size = 8
# Saving model checkpoint to wav2vec2-large-rbg-tamil/checkpoint-5900
# Configuration saved in wav2vec2-large-rbg-tamil/checkpoint-5900/config.json
# Model weights saved in wav2vec2-large-rbg-tamil/checkpoint-5900/pytorch_model.bin
# Configuration saved in wav2vec2-large-rbg-tamil/checkpoint-5900/preprocessor_config.json
# Deleting older checkpoint [wav2vec2-large-rbg-tamil/checkpoint-5700] due to args.save_total_limit
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
# TrainOutput(global_step=5900, training_loss=0.6821578608529042, metrics={'train_runtime': 31423.9361, 'train_samples_per_second': 6.027, 'train_steps_per_second': 0.188, 'total_flos': 2.5117970793502507e+19, 'train_loss': 0.6821578608529042, 'epoch': 50.0})
